# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Train, Validation, and Test Data
data_train = {
    "Epochs": [1, 2, 3, 4, 5, 6, 7, 8],
    "Loss": [0.0036, 0.0010, 0.0005, 0.0003, 0.0005, 0.0004, 0.0002, 0.0001],
    "Accuracy": [0.6185, 0.8004, 0.8615, 0.8921, 0.9022, 0.9218, 0.9347, 0.9467],
    "Precision": [0.5502, 0.8292, 0.8890, 0.9223, 0.9366, 0.9411, 0.9553, 0.9632],
    "Recall": [0.6185, 0.8004, 0.8615, 0.8921, 0.9022, 0.9218, 0.9347, 0.9467],
    "F1": [0.5355, 0.7764, 0.8554, 0.8868, 0.9042, 0.9200, 0.9375, 0.9484],
}

data_validation = {
    "Epochs": [1, 2, 3, 4, 5, 6, 7, 8],
    "Loss": [0.0038, 0.0013, 0.0007, 0.0006, 0.0006, 0.0006, 0.0005, 0.0005],
    "Accuracy": [0.6169, 0.7982, 0.8468, 0.8784, 0.8793, 0.9074, 0.9177, 0.9177],
    "Precision": [0.5135, 0.7908, 0.8636, 0.9080, 0.9098, 0.9300, 0.9366, 0.9177],
    "Recall": [0.6169, 0.7982, 0.8468, 0.8784, 0.8793, 0.9074, 0.9177, 0.9177],
    "F1": [0.5359, 0.7713, 0.8361, 0.8701, 0.8765, 0.9077, 0.9161, 0.9177],
}

data_test = {
    "Epochs": [1, 2, 3, 4, 5, 6, 7, 8],
    "Loss": [0.0036, 0.0011, 0.0007, 0.0006, 0.0005, 0.0005, 0.0005, 0.0005],
    "Accuracy": [0.6271, 0.7987, 0.8500, 0.8810, 0.8899, 0.9157, 0.9243, 0.9243],
    "Precision": [0.5356, 0.8039, 0.8797, 0.8959, 0.9196, 0.9325, 0.9393, 0.9243],
    "Recall": [0.6271, 0.7987, 0.8500, 0.8810, 0.8899, 0.9157, 0.9243, 0.9243],
    "F1": [0.5449, 0.7728, 0.8426, 0.8765, 0.8921, 0.9168, 0.9250, 0.9243],
}

# Convert to DataFrames
df_train = pd.DataFrame(data_train)
df_validation = pd.DataFrame(data_validation)
df_test = pd.DataFrame(data_test)

# Set plot style
sns.set(style="whitegrid")

# Create a figure with subplots for multiple metrics
fig, axs = plt.subplots(2, 2, figsize=(10, 8))  # 3 rows, 2 columns for 5 plots

# Plot for Loss
sns.lineplot(x="Epochs", y="Loss", data=df_train, marker="o", label="Train", color="blue", ax=axs[0, 0])
sns.lineplot(x="Epochs", y="Loss", data=df_validation, marker="o", label="Validation", color="green", ax=axs[0, 0])
sns.lineplot(x="Epochs", y="Loss", data=df_test, marker="o", label="Test", color="red", ax=axs[0, 0])
axs[0, 0].set_title("Loss Over Epochs")
axs[0, 0].set_xlabel("Epochs")
axs[0, 0].set_ylabel("Loss")
axs[0, 0].legend()

# Plot for Accuracy
sns.lineplot(x="Epochs", y="Accuracy", data=df_train, marker="o", label="Train", color="blue", ax=axs[0, 1])
sns.lineplot(x="Epochs", y="Accuracy", data=df_validation, marker="o", label="Validation", color="green", ax=axs[0, 1])
sns.lineplot(x="Epochs", y="Accuracy", data=df_test, marker="o", label="Test", color="red", ax=axs[0, 1])
axs[0, 1].set_title("Accuracy Over Epochs")
axs[0, 1].set_xlabel("Epochs")
axs[0, 1].set_ylabel("Accuracy")
axs[0, 1].legend()

# Plot for Precision
sns.lineplot(x="Epochs", y="Precision", data=df_train, marker="o", label="Train", color="blue", ax=axs[1, 0])
sns.lineplot(x="Epochs", y="Precision", data=df_validation, marker="o", label="Validation", color="green", ax=axs[1, 0])
sns.lineplot(x="Epochs", y="Precision", data=df_test, marker="o", label="Test", color="red", ax=axs[1, 0])
axs[1, 0].set_title("Precision Over Epochs")
axs[1, 0].set_xlabel("Epochs")
axs[1, 0].set_ylabel("Precision")
axs[1, 0].legend()

# Plot for Recall
sns.lineplot(x="Epochs", y="Recall", data=df_train, marker="o", label="Train", color="blue", ax=axs[1, 1])
sns.lineplot(x="Epochs", y="Recall", data=df_validation, marker="o", label="Validation", color="green", ax=axs[1, 1])
sns.lineplot(x="Epochs", y="Recall", data=df_test, marker="o", label="Test", color="red", ax=axs[1, 1])
axs[1, 1].set_title("Recall Over Epochs")
axs[1, 1].set_xlabel("Epochs")
axs[1, 1].set_ylabel("Recall")
axs[1, 1].legend()

"""# Plot for F1
sns.lineplot(x="Epochs", y="F1", data=df_train, marker="o", label="Train", color="blue", ax=axs[2, 0])
sns.lineplot(x="Epochs", y="F1", data=df_validation, marker="o", label="Validation", color="green", ax=axs[2, 0])
sns.lineplot(x="Epochs", y="F1", data=df_test, marker="o", label="Test", color="red", ax=axs[2, 0])
axs[2, 0].set_title("F1 Over Epochs")
axs[2, 0].set_xlabel("Epochs")
axs[2, 0].set_ylabel("F1")
axs[2, 0].legend()
"""
# Hide the empty subplot in the last position (since we only have 5 metrics)
#axs[2, 1].axis('off')

# Adjust layout
plt.tight_layout()
plt.show()
